# %% [markdown]
# # Latar Belakang
# suatu perusahaan penerbangan memerlukan perbaikan mutu untuk meningkatkan kualitas dari layanan yang digunakan,namun dengan keterbatasan dari cost dan waktu yang digunakan,maka diperlukan perbaikan mutu secara bertahap dulu yang berfokus pada keefektifan layanan yang digunakan dan diharapkan perbaikan peningkatkan layanan yang dipilih tepat sasaran ke orang-orang yang membutuhkan layanan tersebut.

# %% [markdown]
# Muhammad bari alfattah
# Capstone 2
# JCDSOL-009-041

# %% [markdown]
# # Pernyataan masalah
# Perusahaan penerbangan membutuhkan Perbaikan mutu secara bertahap dan tepat sasaran,dari pernyataan tersebut dapat dirumuskan masalah yang dicari yaitu adalah :
#
# **1.Apa saja Karateristik dari mutu yang ada pada penerbangan**
#
# **2.Bagaimana hubungan antara pelayanan & Karateristik dengan kepuasan pelanggan**

# %%
train.to_csv('train after cleaning',index=False)

# %% [markdown]
# # Data
# untuk data yang digunakan dapat diakses [disini](https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy.stats import normaltest, chi2_contingency, mannwhitneyu, ttest_ind

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Dataset yang digunakan berisi tentang survei kepuasan penumpang maskapai penerbangan yang terbagi menjadi file train dan test, test berisi tentang 20% dari datase dan train berisi 80% dari dataset.
#
# content dari data adalah :
# * Gender: Gender of the passengers (Female, Male)
#
# * Customer Type: The customer type (Loyal customer, disloyal customer)
#
# * Age: The actual age of the passengers
#
# * Type of Travel: Purpose of the flight of the passengers (Personal Travel, Business Travel)
#
# * Class: Travel class in the plane of the passengers (Business, Eco, Eco Plus)
#
# * Flight distance: The flight distance of this journey
#
# * Inflight wifi service: Satisfaction level of the inflight wifi service (0:Not Applicable;1-5)
#
# * Departure/Arrival time convenient: Satisfaction level of Departure/Arrival time convenient
#
# * Ease of Online booking: Satisfaction level of online booking
#
# * Gate location: Satisfaction level of Gate location
#
# * Food and drink: Satisfaction level of Food and drink
#
# * Online boarding: Satisfaction level of online boarding
#
# * Seat comfort: Satisfaction level of Seat comfort
#
# * Inflight entertainment: Satisfaction level of inflight entertainment
#
# * On-board service: Satisfaction level of On-board service
#
# * Leg room service: Satisfaction level of Leg room service
#
# * Baggage handling: Satisfaction level of baggage handling
#
# * Check-in service: Satisfaction level of Check-in service
#
# * Inflight service: Satisfaction level of inflight service
#
# * Cleanliness: Satisfaction level of Cleanliness
#
# * Departure Delay in Minutes: Minutes delayed when departure
#
# * Arrival Delay in Minutes: Minutes delayed when Arrival
#
# * Satisfaction: Airline satisfaction level(Satisfaction, neutral or dissatisfaction)

# %%
#menggunakan data yang digunakan yaitu data dari costumer analysis untuk train dan test
test=pd.read_csv(r'C:/Users/bari alfattah/Desktop/test.csv')
train=pd.read_csv(r'C:/Users/bari alfattah/Desktop/train.csv')

# %%
#menampilkan data yang digunakan 
display(test.head(5),test.tail(5),train.head(5),train.tail(5))
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# ...

# %%
#mengecek data yang digunakan 
display(train.describe(),train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
#mengecek pilihan dari opsi yang berbentuk
train.head(3)
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# ...

# %%
#mengecek kecocokan data yang digunakan
display(train[['Gender']].value_counts(),train['Customer Type'].value_counts(),train['satisfaction'].value_counts(),train['Type of Travel'].value_counts(),train['Class'].value_counts())
# Out:
# Gender
# Female    52727
# Male      51177
# dtype: int64
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64

# %%
#mengecek value pada objek apakah sesuai
display(train.describe().loc[['min']],train.describe().loc[['max']])
# Out:
#      Unnamed: 0   id  Age  Flight Distance  Inflight wifi service  \
# min         0.0  1.0  7.0             31.0                    0.0
#
#      Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# min                                0.0                     0.0            0.0
#
#      Food and drink  Online boarding  Seat comfort  Inflight entertainment  \
# min             0.0              0.0           0.0                     0.0
#
#      On-board service  Leg room service  Baggage handling  Checkin service  \
# min               0.0               0.0               1.0              0.0
#
#      Inflight service  Cleanliness  Departure Delay in Minutes  \
# min               0.0          0.0                         0.0
#
#      Arrival Delay in Minutes
# min                       0.0
#      Unnamed: 0        id   Age  Flight Distance  Inflight wifi service  \
# max    103903.0  129880.0  85.0           4983.0                    5.0
#
# ...

# %% [markdown]
# # Data Cleaning
#  Karena pengecekan data sudah dilakukan bisa dilanjutkan dengan menghapus data yang dinilai tidak dipakai yaitu adalah kolom id dan unnamed yang tidak terlalu dipakai pada penilaian

# %%
train.drop(["Unnamed: 0","id"],axis=1,inplace = True)

# %%
train
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %%
#MENGECEK NILAI KOSONG PADA data set
train.isna().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %%
#melihat distribusi pada mean arrival
sns.histplot(train['Arrival Delay in Minutes'],kde=True)
plt.show()

# %%
#d agustino test
from scipy.stats import normaltest
normaltest(train['Arrival Delay in Minutes'])
# Out:
# NormaltestResult(statistic=nan, pvalue=nan)

# %%
#mengisi missing value menggunakan median
#karena persebaran pada Grafik dinilai tidak terdistribusi normal maka cara yang baik adalah mengisi nilai keterlambatan dengan median
# Imputing missing value with median
train['Arrival Delay in Minutes'] = train['Arrival Delay in Minutes'].fillna(train['Arrival Delay in Minutes'].median())

# %%
train.isna().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
cat_columns = train.select_dtypes(object).columns.to_list()
print(cat_columns)
print()
num_columns = train.select_dtypes(np.number).columns.to_list()
print(num_columns)
# Out:
# ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']
#
# ['Age', 'Flight Distance', 'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']

# %% [markdown]
# # Data Understanding

# %%
#membuat visualisasi data pada data object
fig, axes = plt.subplots(2, 3, figsize = (20, 12))
sns.countplot(x = 'Gender', data = train, palette= 'winter', ax = axes[0, 0]);
sns.countplot(x = 'Customer Type', data = train, palette= 'winter', ax = axes[0, 1]);
sns.countplot(x = 'Type of Travel', data= train, palette= 'winter', ax = axes[0, 2]);
sns.countplot(x = 'Class', data = train, palette= 'winter', ax = axes[1, 0]);
sns.countplot(x = 'satisfaction', data = train, palette= 'winter', ax = axes[1, 1]);
sns.histplot(x = 'Age', data = train, palette= 'winter', ax = axes[1, 2]);

# %% [markdown]
# Karateristik penumpang dapat disimpulkan menjadi :
# -penumpang pada pesawat terdiri dari komposisi gender yang hampir sama antara laki-laki dan perempuan
#
# -Kebanyakan penumpang pesawat adalah penumpang yang sering menaiki pesawat dengan total kurang lebih 80% lebih penumpang loyal
#
# -kebanyakan penumpang yang menaiki pesawat adalah penumpang yang memiliki tujuan bisnis yang berkisar kurang lebih 70 pesen dari total penumpang
#
# -Mayoritas kurang lebih 50 persen adalah penumpang yang berada dikelas bisnis dan sisanya adalah Penumpang yang berada pada kelas eco, baik eco plus dan eco
# -Nilai kepuasan penumpang berada diatas rata-rata lebih dari 50 persen
# -Umur perserta beragam dengan Kebanyakan penyebaran umur berpusat  pada umur  30-60 tahun dan rata-rata umur 39,3 tahun

# %%
#melihat persebaran jadwal penerbangan dan umur
plt.figure(figsize=(14,8))
sns.histplot(train['Age'])
plt.show()

plt.figure(figsize=(14,8))
sns.histplot(train['Flight Distance'])
plt.show()

# %%
#mengecek distribusi umur  apakah terdistribusi normal atau tidak
#d agustino test
from scipy.stats import shapiro
shapiro(train['Age'])


d_statistic,d_pvalues=shapiro(train['Age'])
if d_pvalues>=0.05:
    print(' umur terdistribusi normal')
else:
    print('umur terdistribusi tidak  normal')
# Out:
# umur terdistribusi tidak  normal

# %%
#mengecek distribusi umur  apakah terdistribusi normal atau tidak
#shapiro test
#pake shapiro
from scipy.stats import shapiro
shapiro(train['Flight Distance'])



p_statistic,p_pvalues=shapiro(train['Flight Distance'])
if p_pvalues>=0.05:
    print(' Flight distance terdistribusi normal')
else:
    print('flight distance terdistribusi tidak  normal')
# Out:
# flight distance terdistribusi tidak  normal

# %%
#melihat pola persebaran menggunakan box plot pada flight distance dan age
sns.boxplot(x=train['Age'])
plt.title('Tip Boxplot',size=20)
plt.show()

sns.boxplot(x=train['Flight Distance'])
plt.title('Tip Boxplot',size=20)
plt.show()

# %%
pada distribusi flight distance data cenderung condong ke kiri dan banyak outlier pada titik maksimum
pada umur data juga cenderung kiri dan tidak banyak terjadi outlier
3 kedua data menggunakan uji shapiro wilk menunjukkan distribusi yang tidak normal

# %%
#melihat hubungan kelas dengan Umur
f, ax = plt.subplots(1, 2, figsize = (15,5))
sns.boxplot(x = "Class", y = "Age", palette = "pastel", data = train, ax = ax[0])
sns.histplot(train, x = "Age", hue = "Class", multiple = "stack", palette = "pastel", edgecolor = ".3", linewidth = .5, ax = ax[1])
pass

# %% [markdown]
# dari penyebaran jarak tempuh penumpang dapat dilihat penyebaran data berpusat kearah kiri yang berkisar antara 200-1500 KM
#
# sehingga dapat diasumsikan :
# -Kebanyakan penumpang adalah penumpang loyal yang berada pada umur produktif berkerja yaitu 20-60 tahun, dan tujuan bisnis,hal ini dapat menjadi kesimpulan bahwa Tujuan Penumpang menaiki pesawat kebanyakan murni karena perkerjaan yang dilakukan.
# -Dengan jarak tempuh yang menyebar kekiri dan umur produktif dapat disimpulkan bisnis dilalui adalah tujuan menaiki pesawat adalah bisnis yang memiliki jarak dekat.
# -Gender yang menaiki seimbang antara laki-laki dan perempuan sehingga dapat diasumsikan, kebanyakan yang menaiki pesawat adalah dengan tujuan perkerjaan namun dengan keragaman yang sama antara tiap gender.
# -Persebaran disloyal dan loyal costumer merata pada seluruh umur jadi penilaian terhadap disloyal dan loyal tidak ada korelasi.

# %%
#membuat data 
def bar_plot(variable):
    
    var=train[variable]
    var_Value=var.value_counts()
    
    #visualize
    plt.figure(figsize=(9,3))
    plt.bar(var_Value.index,var_Value.values)
    
    plt.xlabel("Penilaian Penumpang")
    plt.ylabel("Frekuensi")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,var_Value))
category1=["Inflight wifi service", "Departure/Arrival time convenient", "Ease of Online booking", "Gate location", "Food and drink", "Online boarding", "Seat comfort", "Inflight entertainment", "On-board service", "Leg room service", "Baggage handling", "Checkin service", "Inflight service", "Cleanliness",]
for c in category1:
    bar_plot(c)
# Out:
# Inflight wifi service:
#  3    25868
# 2    25830
# 4    19794
# 1    17840
# 5    11469
# 0     3103
# Name: Inflight wifi service, dtype: int64
# Departure/Arrival time convenient:
#  4    25546
# 5    22403
# 3    17966
# 2    17191
# 1    15498
# 0     5300
# Name: Departure/Arrival time convenient, dtype: int64
# Ease of Online booking:
#  3    24449
# 2    24021
# 4    19571
# 1    17525
# 5    13851
# 0     4487
# Name: Ease of Online booking, dtype: int64
# Gate location:
#  3    28577
# 4    24426
# 2    19459
# 1    17562
# 5    13879
# 0        1
# Name: Gate location, dtype: int64
# Food and drink:
#  4    24359
# 5    22313
# 3    22300
# 2    21988
# 1    12837
# 0      107
# Name: Food and drink, dtype: int64
# Online boarding:
#  4    30762
# 3    21804
# 5    20713
# 2    17505
# 1    10692
# 0     2428
# Name: Online boarding, dtype: int64
# Seat comfort:
#  4    31765
# 5    26470
# 3    18696
# 2    14897
# 1    12075
# 0        1
# ...

# %%
#melihat persebaran dan hubungan dari arrival dan delay
plt.scatter(train['Arrival Delay in Minutes'], train['Departure Delay in Minutes'], alpha = 0.4)
plt.title('Hubungan antara arrival dan delay')
plt.ylabel('Derpature Delay')
plt.xlabel('Arrival delay')
pass

# %% [markdown]
# Dapat disimpulkan bahwa Arrival dan Delay terdapat korelasi melalui scatter plot diatas,Hal ini dinilai masuk akal karena bila terjadi keterlambatan pada keberangkatan arrival akan mengalami keterlambatan juga.

# %% [markdown]
# # Gender

# %%
#Karateristik dari Penilaian
# create graph

plt.figure(figsize = (5,5))
sns.countplot(x ="Gender", data = train, hue ="satisfaction", palette ="Pastel1" )

# format graph
sns.despine(top = True, right = True, left = False, bottom = False)
plt.title("Satisfaction results by gender")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# Terlihat bahwa antara gender perempuan dan laki-laki tidak terdapat sedikit perbedaan antara keduanya,dengan penilaian bahwa kedua gender tidak puas terhadap Penerbangan yang dilaksanakan

# %%
train.info()
#ada 11 objektif
# dan ada 14 penilaian 
#karena fokus kita adalah kearah managemen penerbangan jadi yang kita lakukan adalah mencari data dalam keadaan penerbangan
#dan unutk yang 11 kita fokus ke arah penentuan kelas gender dan waktu sebelum dan sesudah mereka terbang
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
# ...

# %% [markdown]
# # Type of travel

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Type of Travel", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title("Satisfaction results by Type of Travel")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# Terdapat hal yang sangat menarik yaitu pada Penilaian dari personal travel dan business travel,yaitu penilaian kepuasan sangat bernilai tinggi untuk yang memilih nilai kepuasan terlihat bahwa pada para penumpang yang bertujuan peronal travel kepuasan bernilai sangat rendah dibandingkan ketidakpuasan dan sebaliknya bahwa pada yang memiliki business travell banyak yang puas dengan penilaian,hal ini menunjukkan bahwa servis yang diberikan fokus kepada tujuan business dan perlu peningkatan untuk tujuan personal travel.

# %% [markdown]
# # Age

# %%
# create graph
plt.figure(figsize = (8,5))
sns.histplot( x= "Age", data = train, kde= True,hue="satisfaction")

# format graph
plt.title("Distribution of age")
plt.show()
# create graph
plt.figure(figsize = (8,5))
sns.kdeplot(data = train, x= "Age", hue = "satisfaction", common_norm = False, palette ="RdPu_r")

# format graph
plt.title("Satisfaction results by age")
sns.despine(top = True, right = True, left = False, bottom = False)
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")
plt.axvline(train["Age"].mean(),ls = "--", color = "red")
plt.text(train["Age"].mean()-2,0,'average',rotation=90)
plt.show()

# %% [markdown]
# dari data tersebut dapat dikategorikan menjadi berbagai tipe diantaranya :
#
# umur <40 terlihat bahwa kepuasan berada dibawah ketidakpuasan dan terjadi secara konsisten hal ini menjadi penilaian yang dapat dipertimbangkan dalam  layanan pada umur dibawah rentang tersebut .
#
# umur >40 & > 60> terlihat bahwa untuk pada rentang tersebut nilai kepuasan berada diatas ketidakpuasan,dapat disumpulkan juga bahwa pelayanan pada rentang tersebut berada pada nilai terbaiknya,hal ini dapat menjadi acuan bahwa pelayanan pada umur segitu dinilai cukup baik.
#
# umur <60 nilai kepuasan menurun lagi dibawah nilai ketidakpuasan hal ini dapat menjadi pertimbangan untuk pelayanan yang lebih friendly untuk umur tersebut.

# %% [markdown]
# # Class

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Class", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title("Satisfaction results by Class")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# Terlihat pada barplot bahwa nilai kelas eco memiliki tingkat ketidakpuasaan yang sangat tinggi dibandingkan ketidakpuasanya,hal ini berbanding terbalik pada business class dan dapat menjadi suatu asumsi bahwa untuk melakukan peningkatan dalam penerbangan,hal yang menjadi fokus adakah memperbaiki layanan pada eco class dalam penerbangan

# %% [markdown]
# # Type costumer

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Customer Type", data = train, hue ="satisfaction" ,palette ="Pastel1" )

# format graph
plt.title("Satisfaction results by Customer Type")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# Disloyal customer memiliki nilai yang sangat jauh terhadap dari loyal costumer dalam penilaian kepuasannya,walau secara keduanya nilai dari kepuasan pada costumer yang loyal dan disloyal masih dominan terhadap tidak puas,hal ini menjadi penilian bahwa peningkatan layanan sangat diperlukan untuk menaikkan nilai mutu dari layanan.

# %%
f, ax = plt.subplots(figsize = (12,8))
train["Type of Travel"].hist(by = train["Class"],xrot =30,ax=ax)
plt.show()

# %% [markdown]
# Dapat dsimpulkan juga salah satu kenapa penilaian kepuasan cukup berbeda jauh pada personal travel dikarenakan kebanyakan penumpang lebih memilih berada dikelas business yang dapat menjadi alasan mengapa personal travel menilai kepuasan sangat rendah.

# %% [markdown]
# # Flight distance

# %%
# create graph
sns.displot(x = "Flight Distance", data = train, hue ="satisfaction", height = 8,palette ="RdPu_r"  )
plt.title("Satisfaction results by Flight Distance")
# Out:
# Text(0.5, 1.0, 'Satisfaction results by Flight Distance')

# %% [markdown]
# dapat dilihat bahwa pada penerbangan jarak dekat nilai kepuasan berada dibawah ketidakpuasan dengan selisih lumayan jauh,tetapi hal ini berbanding terbalik dengan penerbangan jarak jauh yang menilai bahwa sangat puas untuk layanan yang diberikan,hal ini dapat menjadi petunjuk bahwa layanan untuk penerbangan jarak jauh sudah sangat baik

# %%
f, ax = plt.subplots(1, 2, figsize = (15,5))
sns.boxplot(x = "Class", y = "Flight Distance", palette = "pastel", data = train, ax = ax[0])
sns.histplot(train, x = "Flight Distance", hue = "Class", multiple = "stack", palette = "pastel", edgecolor = ".3", linewidth = .5, ax = ax[1])
pass

# %% [markdown]
# Dapat disimpulkan bahwa kebanyakan penumpang yang memiliki rute sangat jauh berada dikelas bisnis has ini menjelaskan antara hubungan jauhnya penerbangan dan kepuasan yang terjadi

# %% [markdown]
# # Derpature/Arrival convinence

# %%
# Departure/Arrival time convenient: Satisfaction level of Departure/Arrival time convenient

# create graph
plt.figure(figsize = (8,5))
sns.countplot(x = "Departure/Arrival time convenient", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title("Satisfaction results by Departure/Arrival time convenient")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# Penilaian untuk jadwal dinilai tidak berpangaruh signifikan terhadap penilaian kepuasan,hal ini dapat terlihat bahwa walau sudah memberi nilai yang sangat baik,penilaian ketidakpuasan masih tinggi pada penilaian

# %% [markdown]
# # Wifi service

# %%
# Inflight wifi service: Satisfaction level of the inflight wifi service (0:Not Applicable;1-5)


# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Inflight wifi service", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title("Satisfaction results by Wifi service")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# Wifi service menjadi salah satu penilaian yang berdampak penting dalam kepuasan,dilihat bahwa saat memberi nilai tinggi pada wifi service tingkat kepuasan sangatlah berdampak,namun perlu diperhatikan juga kebanyakan data berpusat pada penilaian ditengah,hal ini menjadi pertimbangan walau wifi service menjadi pengaruh yang penting namun layanan wifi secara keseluruhan masih perlu ditingkat, oleh karena itu kita coba lihat untuk pembagian kelas yang diberikan:

# %%
sns.catplot(x='Class', y="Inflight wifi service", hue="satisfaction",data= train)
plt.title = ('Effect of on-board service on satisfaction in different classes')

# %% [markdown]
# Dapat dilihat dari gambar tersebut salah satu faktor peningkatan yang untuk wifi service adalah peningkatan untuk kelas bisnis secara spesifik agar dapat meningkatkan mutu terhadap kepuasan.

# %% [markdown]
# # Gate of location

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Gate location", data = train, hue ="satisfaction",palette ="Pastel1" )
plt.title = ('Effect of gate location on satisfaction')
# format graph
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %%
Tidak terlihat secara jelas hubungan antara gate location dengan kadar kepuasan pada penilaian,jadi dinilai gate location tidak berpengaruh secara spesifik terhadap kepuasan.

# %% [markdown]
# # Ease Online Booking

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x = "Ease of Online booking", data = train, hue ="satisfaction",palette ="Pastel1" )
plt.title = ('Effect of on-online booking')
# format graph
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# terdapat banyak asumsi untuk kepuasan dengan kemudahan booking kita akan korelasikan dengan umur dan tujuan travel :

# %%
# create graph
sns.displot(x = "Age",y='Ease of Online booking', data = train, hue ="satisfaction", height = 8,palette ="RdPu_r"  )
plt.title = ('Effect of on Ease online booking on satisfaction in different classes')

# %% [markdown]
# tidak terdapat hubungan antara umur dengan penilaian terhadap kepuasan dalam kemudahan dalam pemesanan,hal ini sangat tidak berbanding dengan yang dipikirkan yaitu bahwa kebanyakan orang-orang yang berada diusia lanjut usia dinilai tidak bisa memesan secara online,selanjutnya akan dicoba dengan perbandingan terhadap kelas yang dipilih:

# %%
sns.catplot(x='Type of Travel', y="Ease of Online booking", hue="satisfaction",data= train)
plt.title = ('Effect of on-board service on satisfaction in different classes')

# %% [markdown]
# untuk personal travel bila Kemudahan untuk online booking baik dinilai kepuasannya akan meningkat.

# %% [markdown]
# # online boarding

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Online boarding", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title=("Satisfaction results by Online boarding")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# Terlihat bahwa online boarding sangat mempengaruhi nilai kepuasan pada penilaian, bila online boardingnya tinggi maka kepuasaanya akan tinggi juga, kita akan coba melihat dari pembagian kelas pada online boarding :

# %%
sns.catplot(x='Class', y='Online boarding', hue="satisfaction",data= train)
plt.title = ('Effect of on-board service on satisfaction in different classes')

# %% [markdown]
# Terlihat online boarding sangat mempengaruhi penilaian dan hal ini berlaku untuk semua kelas yang ada pada penerbangan

# %% [markdown]
# # seated confort & Leg room service

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Seat comfort", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title=("Satisfaction results by Seat comfort")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ='Leg room service', data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title=("Satisfaction results by Seat comfort")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

f, ax = plt.subplots(1, 2, figsize = (20,5))
sns.countplot(x = 'Seat comfort', hue = 'satisfaction', palette = "YlOrBr", data = train,ax = ax[0])
sns.countplot(x = 'Leg room service', hue = 'satisfaction', palette = "YlOrBr", data = train, ax = ax[1])
plt.show()

# %% [markdown]
# Terlihat bahwa Nilai seat comfort dan leg room service memiliki penilaian yang relatif sama,dikarenakan aspek penilaian yang dipilih dan dinilai bermakna sama,dan pada grafik menunjukkan bahwa kedua kondisi juga berhubungan dengan nilai kepuasan pada penerbangan yang dilalui

# %% [markdown]
# # on-board service

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="On-board service", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title=("Satisfaction results by Food and drink")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# # cleanliness

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Cleanliness", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title=("Satisfaction results by Cleanliness")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %%
Cleanliness terlihat berpengaruh pada kepuasan untuk lebih lengkapnya kita lihat dari kelas dan tipe dari penumpang :

# %%
sns.catplot(x='Class', y='Cleanliness', hue="satisfaction",data= train)
plt.title = ('Effect of on-board service on satisfaction in different classes')

sns.catplot(x='Gender', y='Cleanliness', hue="satisfaction",data= train)
plt.title = ('Effect of on-board service on satisfaction in different classes')

# %% [markdown]
# Terlihat bahwa pada penumpang yang berada dikelas bisnis memiliki kecenderungan memberi nilai puas bila nilai kebersihan tinggi,dan untuk penumpang berdasarkan gender baik perempuan atau laki-laki tidak terjadi perbedaan kecenderungan pada penilaian kebersihan dengan kepuasan

# %% [markdown]
# # baggage handling

# %% [markdown]
# dalam baggage handling tidak terdapat dampak yang signifikan terhadap nilai kepuasan

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Baggage handling", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title=("Satisfaction results by Food and drink")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# # check in service

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Checkin service", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title=("Satisfaction results by Food and drink")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# dalam check in service tidak terdapat hubungan yang signifikan dengan kepuasan

# %% [markdown]
# # in flight entertaiment

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Inflight entertainment", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title=("Satisfaction results by Inflight entertainment")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %%
Untuk inflight intertaiment terdapat juga penilaian antara kepuasan dengan nilai kepuasan,oleh lebih jelasnya kita bisa bandingkan dengan waktu tempuh dan kelas pada penerbangan:

# %%
sns.catplot(x='Class', y="Inflight entertainment", hue="satisfaction",data= train)
plt.title = ('Effect of on-board service on satisfaction in different classes')

# %%
f, ax = plt.subplots(2, 2, figsize = (15,8))
sns.boxplot(x = "Inflight entertainment", y = "Flight Distance", palette = "pastel", data = train, ax = ax[0, 0])
sns.histplot(train, x = "Flight Distance", hue = "Inflight entertainment", multiple = "stack", palette = "pastel", edgecolor = ".3", linewidth = .5, ax = ax[0, 1])
sns.boxplot(x = "Leg room service", y = "Flight Distance", palette = "pastel", data = train, ax = ax[1, 0])
sns.histplot(train, x = "Flight Distance", hue = "Leg room service", multiple = "stack", palette = "pastel", edgecolor = ".3", linewidth = .5, ax = ax[1, 1])
pass

# %% [markdown]
# Terlihat bahwa semakin panjang perjalanan maka kecenderungan untuk memberi nilai kepuasan tinggi cenderung juga besar,hal ini juga berlaku terhadap nilai kenyamanan kaki yang menjadi salah satu faktor perjalanan panjang.
# hal ini juga menjadi catatan karena kebanyakan perjalanan panjang berada pada kelas bisnis

# %% [markdown]
# # in flight service

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Inflight service", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title=("Satisfaction results by Food and drink")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# dalam inflight service tidak terjadi hubungan yang signifikan dengan kepuasan

# %% [markdown]
# # food and drink

# %%
# create graph
plt.figure(figsize = (8,5))
sns.countplot(x ="Food and drink", data = train, hue ="satisfaction",palette ="Pastel1" )

# format graph
plt.title=("Satisfaction results by Food and drink")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),  title = "satisfaction")

plt.show()

# %% [markdown]
# hubungan antara makanan dengan kepuasan penerbangan dinilai bernilai memiliki kolerasi yang lemah,namun kita coba hubungkan dengan penilaian pada kelas yang tersedia dan dengan tujuan travel :

# %%
sns.catplot(x='Class', y='Food and drink', hue="satisfaction",data= train)
plt.title = ('Effect of on-board service on satisfaction in different classes')

sns.catplot(x='Type of Travel', y='Food and drink', hue="satisfaction",data= train)
plt.title = ('Effect of on-board service on satisfaction in different classes')

# %%
Pada kelas Ekonomi ada kecenderungan untuk tidak puas bila makanan memiliki penilaian rendah,namun untuk tujuan travel korelasi tidak terlihat antara makanan dengan penilaian kepuasan

# %% [markdown]
# # Kesimpulan
#
# kebanyakan penumpang yang menaiki pesawat adalah penumpang yang memiliki tujuan bisnis dan sering naik pesawat namun tingkat kepuasan dinilai masih kurang
#
# Peningkatan Personal travel untuk kelas ekonomi diperlukan dikarenakan kebanyakan personal travel yang dikelas ekonomi memberi nilai tidak puas
#
# Terlihat bahwa online boarding sangat mempengaruhi nilai kepuasan pada penilaian, bila online boardingnya tinggi maka kepuasaanya akan tinggi juga, kita akan coba melihat dari pembagian kelas pada online boarding
#
# Meningkatkan layanan wifi secara spesifik dikelas ekonomi dapat menjadi salah satu usulan untuk meningkatkan kepuasan
#
# Meningkatkan Kebersihan dikelas bisnis dapat mempengaruhi penilaian kepuasan menjadi lebih baik
#
# Peningkatan entertaiment dan leg service pada kelas ekonomi perlu dilakukan untuk menaikkan nilai kepuasan
#
# layanan makanan perlu diperhatikan dikarenakan kebanyakan kelas ekonomi memberi kepuasan yang tinggi bila makanan bagus
